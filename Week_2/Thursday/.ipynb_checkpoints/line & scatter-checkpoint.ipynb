# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ### Table of Contents
#
# 1.  <a href='#section 1'>Line graphs</a>
#
#     a. <a href='#subsection 1a'> Comparing Years </a> <br><br>
#     b. <a href='#subsection 1b'> Comparing Sex </a> <br><br>
#
# 2. <a href='#section 2'>Scatter plots</a>

# %% [markdown]
# ---
#
# ## The Data <a id='data'></a>
#
# Today, we will continue work with the US census data, just looking at years 2010 and 2014.
# As a reminder, the `SEX` column contains numeric codes: `0` stands for the total, `1` for male, and `2` for female. The `AGE` column contains ages in completed years, but the special value `999` is a sum of the total population.
#
#
#
# ---

# %%
data = 'http://www2.census.gov/programs-surveys/popest/datasets/2010-2015/national/asrh/nc-est2015-agesex-res.csv'

# A local copy can be accessed here in case census.gov moves the file:
# data = path_data + 'nc-est2015-agesex-res.csv'

full_census_table = Table.read_table(data)
partial_census_table = full_census_table.select('SEX', 'AGE', 'POPESTIMATE2010', 'POPESTIMATE2014')
us_pop = partial_census_table.relabeled('POPESTIMATE2010', '2010').relabeled('POPESTIMATE2014', '2014')
us_pop.sort('AGE')
# Out:
# SEX  | AGE  | 2010    | 2014
# 0    | 0    | 3951330 | 3949775
# 1    | 0    | 2018420 | 2020326
# 2    | 0    | 1932910 | 1929449
# 0    | 1    | 3957888 | 3949776
# 1    | 1    | 2020332 | 2018401
# 2    | 1    | 1937556 | 1931375
# 0    | 2    | 4090862 | 3959664
# 1    | 2    | 2088685 | 2023673
# 2    | 2    | 2002177 | 1935991
# 0    | 3    | 4111920 | 4007079
# ... (296 rows omitted)

# %% [markdown]
# ## 1. Line Graphs <a id='section 1'></a>

# %% [markdown]
# Let's visualize our data!

# %% [markdown]
# <div class="alert alert-warning">
#
# <b>Question 1:</b> Let's start by dropping the `999` code from age, and only looking at totals across sex. Fill in the blanks below:

# %%
no_999 = us_pop.where('AGE', are.below(999))
everyone = no_999.where(...).drop('SEX') ## YOUR CODE HERE
everyone

# %%
# ANSWER KEY
no_999 = us_pop.where('AGE', are.below(999))
everyone = no_999.where('SEX', 0).drop('SEX')
everyone
# Out:
# AGE  | 2010    | 2014
# 0    | 3951330 | 3949775
# 1    | 3957888 | 3949776
# 2    | 4090862 | 3959664
# 3    | 4111920 | 4007079
# 4    | 4077551 | 4005716
# 5    | 4064653 | 4006900
# 6    | 4073013 | 4135930
# 7    | 4043046 | 4155326
# 8    | 4025604 | 4120903
# 9    | 4125415 | 4108349
# ... (91 rows omitted)

# %% [markdown]
# Now, lets plot population counts in 2010, with age on the x-axis.

# %%
everyone.plot('AGE', '2010')

# %% [markdown]
# <div class="alert alert-warning">
# <b> Question 2</b>: Discuss: What are some interesting trends you notice from this line graph?

# %% [markdown]
# <b> YOUR ANSWER HERE: </b>

# %% [markdown]
# Let's take a look at our table again. What if we wanted to compare population counts in 2010 and 2014?

# %%
everyone
# Out:
# AGE  | 2010    | 2014
# 0    | 3951330 | 3949775
# 1    | 3957888 | 3949776
# 2    | 4090862 | 3959664
# 3    | 4111920 | 4007079
# 4    | 4077551 | 4005716
# 5    | 4064653 | 4006900
# 6    | 4073013 | 4135930
# 7    | 4043046 | 4155326
# 8    | 4025604 | 4120903
# 9    | 4125415 | 4108349
# ... (91 rows omitted)

# %% [markdown]
# In the previous example, we specified `2010` as the values we wanted for the y-axis. If we want all of the other columns in the table to be plotted, we only have to specify the argument for the x-axis to `.plot`.

# %% [markdown]
# <div class="alert alert-warning">
# <b> Question 3: </b> Fill in the code to plot population counts in both 2010 and 2014.
#     <a id='subsection 1a'></a>

# %%
....plot(...) # YOUR CODE HERE

# %%
#ANSWER KEY:
everyone.plot("AGE")

# %% [markdown]
# <div class="alert alert-warning">
# <b> Question 4</b>: Discuss: What do you notice when comparing the plots for 2010 and 2014?

# %% [markdown]
# <b> YOUR ANSWER HERE: </b>

# %% [markdown]
# ANSWER KEY: gold graph (for 2014) looks a lot like the graph for 2010, shifted right by ~ 4 years. People who were 20 in 2010 are 24 in 2014 (there are a few more 24 year-olds in 2014 because of immigration). In later ages, the numbers dwindle a little bit because of higher numbers of death/less immigration. Discuss immigration/how it affects census.

# %% [markdown]
# We just compared population counts between different years, what if we wanted to compare plots between sex? <a id='subsection 1b'></a>

# %% [markdown]
# <div class="alert alert-warning">
# <b> Question 5: </b> Fill in the code to construct a table of male and female population counts in 2014.

# %%
both_sexes = us_pop.where('AGE', are.below(999)).where('SEX', are.above(0))
males = both_sexes.where('SEX', 1).column("2014")
females = both_sexes.where(...).column(...) ## YOUR CODE HERE
by_sex = Table().with_columns("Age", np.arange(0, 101), "Males", ..., "Females", ...)
by_sex
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-6bef86e71c56> in <module>
#       1 both_sexes = us_pop.where('AGE', are.below(999)).where('SEX', are.above(0))
#       2 males = both_sexes.where('SEX', 1).column("2014")
# ----> 3 females = both_sexes.where(...).column(...) ## YOUR CODE HERE
#       4 by_sex = Table().with_columns("Age", np.arange(0, 101), "Males", ..., "Females", ...)
#       5 by_sex
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in where(self, column_or_label, value_or_predicate, other)
#     798         Color | Shape | Amount | Price
#     799         """
# --> 800         column = self._get_column(column_or_label)
#     801         if other is not None:
#     802             assert callable(value_or_predicate), "Predicate required for 3-arg where"
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in _get_column(self, column_or_label)
#    1391             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1392         else:
# -> 1393             assert len(c) == self.num_rows, 'column length mismatch'
#    1394             return c
#    1395
#
# TypeError: object of type 'ellipsis' has no len()

# %%
# ANSWER KEY
both_sexes = us_pop.where('AGE', are.below(999)).where('SEX', are.above(0))
males = both_sexes.where('SEX', 1).column("2014")
females = both_sexes.where('SEX', 2).column("2014")
by_sex = Table().with_columns("Age", np.arange(0, 101), "Males", males, "Females", females)
by_sex
# Out:
# Age  | Males   | Females
# 0    | 2020326 | 1929449
# 1    | 2018401 | 1931375
# 2    | 2023673 | 1935991
# 3    | 2049596 | 1957483
# 4    | 2044517 | 1961199
# 5    | 2044339 | 1962561
# 6    | 2111060 | 2024870
# 7    | 2122832 | 2032494
# 8    | 2105618 | 2015285
# 9    | 2097690 | 2010659
# ... (91 rows omitted)

# %% [markdown]
# <div class="alert alert-warning">
# <b> Question 6: </b> Fill in the code to plot male and female population counts in 2014, per age.

# %%
by_sex.plot(...) ##YOUR CODE HERE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-76ce806f897b> in <module>
# ----> 1 by_sex.plot(...) ##YOUR CODE HERE
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in plot(self, column_for_xticks, select, overlay, width, height, **vargs)
#    2087
#    2088         if column_for_xticks is not None:
# -> 2089             x_data, y_labels = self._split_column_and_labels(column_for_xticks)
#    2090             x_label = self._as_label(column_for_xticks)
#    2091         else:
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in _split_column_and_labels(self, column_or_label)
#    2455     def _split_column_and_labels(self, column_or_label):
#    2456         """Return the specified column and labels of other columns."""
# -> 2457         column = None if column_or_label is None else self._get_column(column_or_label)
#    2458         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    2459         return column, labels
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in _get_column(self, column_or_label)
#    1391             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1392         else:
# -> 1393             assert len(c) == self.num_rows, 'column length mismatch'
#    1394             return c
#    1395
#
# TypeError: object of type 'ellipsis' has no len()

# %%
# ANSWER KEY
by_sex.plot("Age")

# %% [markdown]
# <div class="alert alert-warning">
# <b> Question 7: </b> What do you notice about the above plot?

# %% [markdown]
# <b> YOUR ANSWER HERE: </b>

# %% [markdown]
# ANSWER KEY: discuss when male population count is higher than females and vice versa.

# %% [markdown]
# ## 2. Scatter Plots <a id='section 2'></a>

# %% [markdown]
# Let's go back to the actors table from Week 1.

# %%
actors = Table().read_table("actors.csv").relabeled("Gross", "#1 Movie Gross")
actors
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | #1 Movie Gross
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens | 936.7
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers                 | 623.4
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight              | 534.9
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3                  | 415
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers                 | 623.4
# Eddie Murphy       | 3810.4      | 38               | 100.3             | Shrek 2                      | 441.2
# Tom Cruise         | 3587.2      | 36               | 99.6              | War of the Worlds            | 234.3
# Johnny Depp        | 3368.6      | 45               | 74.9              | Dead Man's Chest             | 423.3
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight              | 534.9
# Scarlett Johansson | 3341.2      | 37               | 90.3              | The Avengers                 | 623.4
# ... (40 rows omitted)

# %% [markdown]
# Let's start by looking at the relationship between `Number of Movies` and `Average per Movie`. Again, we specify our label for the x-axis first, followed by the label for the y-axis.

# %%
actors.scatter("Number of Movies", "Average per Movie") ## RUN THIS CELL

# %% [markdown]
# <div class="alert alert-warning">
# <b> Question 1: </b> What does each point in this plot represent? What are some general patterns you notice?

# %% [markdown]
# <b> YOUR ANSWER HERE: </b>

# %% [markdown]
# ANSWER KEY: Each point represents an actor. General negative association - higher number of movies indicates lower average per movie, why might this be the case?

# %% [markdown]
# Like line graphs, we can plot multiple scatter plots on one graph by only specifying the label for the x-axis.

# %% [markdown]
# <div class="alert alert-warning">
# <b> Question 2: </b> Fill in the code to plot "Number of Movies" against "Total Gross" and "#1 Movie Gross". What do you notice?

# %%
actors.select("Number of Movies", ... , ...).scatter(...) ## YOUR CODE HERE
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-babcebca3772> in <module>
# ----> 1 actors.select("Number of Movies", ... , ...).scatter(...) ## YOUR CODE HERE
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in select(self, *column_or_columns)
#     643         5                | 6
#     644         """
# --> 645         labels = self._varargs_as_labels(column_or_columns)
#     646         table = type(self)()
#     647         for label in labels:
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in _varargs_as_labels(self, label_list)
#    1356         """Converts a list of labels or singleton list of list of labels into
#    1357         a list of labels.  Useful when labels are passed as varargs."""
# -> 1358         return self._as_labels(_varargs_labels_as_list(label_list))
#    1359
#    1360     def _unused_label(self, label):
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in _as_labels(self, label_or_labels)
#    1351     def _as_labels(self, label_or_labels):
#    1352         """Convert single label to list and convert indices to labels."""
# -> 1353         return [self._as_label(s) for s in _as_labels(label_or_labels)]
#    1354
#    1355     def _varargs_as_labels(self, label_list):
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in <listcomp>(.0)
#    1351     def _as_labels(self, label_or_labels):
#    1352         """Convert single label to list and convert indices to labels."""
# -> 1353         return [self._as_label(s) for s in _as_labels(label_or_labels)]
#    1354
#    1355     def _varargs_as_labels(self, label_list):
#
# /srv/app/venv/lib/python3.6/site-packages/datascience/tables.py in _as_label(self, index_or_label)
#    1347             return self.labels[index_or_label]
#    1348         else:
# -> 1349             raise ValueError(str(index_or_label) + ' is not a label or index')
#    1350
#    1351     def _as_labels(self, label_or_labels):
#
# ValueError: Ellipsis is not a label or index

# %% [markdown]
# <b> YOUR ANSWER HERE: </b>

# %%
#ANSWER KEY
actors.select("Number of Movies", "Total Gross", "#1 Movie Gross").scatter("Number of Movies") ## YOUR CODE HERE

# %% [markdown]
# ANSWER KEY: total gross is clearly higher than #1 movie gross. general positive association between number of movies and total gross (higher number of movies associated with higher total gross), with exceptions.

# %% [markdown]
# ---
#
# ## Bibliography

# %% [markdown]
# - John Denero - Data 8X, Census: Males and Females. https://www.youtube.com/watch?v=SAJavz58uHk&feature=youtu.be
# - Ani Adhikari - Data 8X, Charts: Scatter Plots. https://www.youtube.com/watch?v=6mPOvbubJSM&feature=youtu.be
# - Ani Adhikari - Data 8X, Charts: Line Graphs. https://www.youtube.com/watch?v=pcEadlLnFBw&feature=youtu.be

# %% [markdown]
# ---
# Notebook developed by: X, X, X
#
# Data Science Modules: http://data.berkeley.edu/education/modules
